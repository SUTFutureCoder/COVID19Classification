# %% [markdown]
# <a href="https://colab.research.google.com/github/SUTFutureCoder/COVID19Classification/blob/master/Convid19Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -i https://pypi.flyai.com/simple flyai
# Out:
# Looking in indexes: https://pypi.flyai.com/simple
# ...
#      |████████████████████████████████| 17.4MB 66.8MB/s
# ...
#      |████████████████████████████████| 5.2MB 52.9MB/s
# ...
#      |████████████████████████████████| 51kB 6.3MB/s
# ...

# %%
# !rm -rf COVID19Classification
# !git clone https://github.com/SUTFutureCoder/COVID19Classification.git 
# !cd COVID19Classification && mv ./* ../
# !python main.py --EPOCHS 256 --BATCH 128
# Out:
# Cloning into 'COVID19Classification'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 195 (delta 11), reused 20 (delta 7), pack-reused 171
# Receiving objects: 100% (195/195), 104.46 MiB | 10.88 MiB/s, done.
# Resolving deltas: 100% (29/29), done.
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# ('dataset%2FCOVIDClassification%2Ftrain_public.zip', 'total size: ', 14, 'MB')
# [##################################################] 100%('新冠肺炎分类', '数据已经下载到', './data/input/COVIDClassification', '文件夹中。')
# ('本地训练提供', '60%', '的数据，线上训练会提供全量数据。')
# ('数据集详细信息请访问:', '数据来源网络')
# ...

# %% [markdown]
# main.py中最后一行为调用prediction验证功能~解开注释重新执行即可

# %%
# !python main.py
# Out:
# {'label': '0'}
